# %%
a=int(input("Enter first value"))
b=int(input("Enter second value"))

a = a^b
b = a^b
a = a^b
print(f"The swap value is :", a,b)
# Out:
# Enter first value 10
# Enter second value 15
# Thw swap value is  15 10
