# %% [markdown]
# # Check the palindrom number True/False

# %%
def reverseNumber(n):
    copy_n =n
    temp =0
    while(n!=0):
        temp= temp*10 + (n%10)
        n= n//10
    return temp

def palindrome(n):
    reverse = reverseNumber(n)
    
    if (revrseNumber() == palindrome()):
        return True
    return False
n=int(input("enter any number"))
print(palindrome(n))
# Out:
# enter any number 121
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 13
#      11     return False
#      12 n=int(input("enter any number"))
# ---> 13 print(palindrome(n))
#
# Cell In[3], line 9, in palindrome(n)
#       8 def palindrome(n):
# ----> 9     if (revrseNumber() == palindrome()):
#      10         return True
#      11     return False
#
# NameError: name 'revrseNumber' is not defined
